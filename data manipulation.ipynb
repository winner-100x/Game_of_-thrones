# %%
import pandas as pd
import os
import numpy as np
print('numpy, pandas imported...')

print('os imported')
import warnings
print('warnings imported...')
warnings.filterwarnings('ignore')
import time
print('time, date imported')
from datetime import datetime

# For URL use
import urllib3

print('requests, json and urllib3 imported...')


pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
pd.options.display.max_colwidth = None
pd.set_option("display.float_format", lambda x: '%.2f' % x)

from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

# %matplotlib inline

import json
print('json imported...')
from pandas.io.json import json_normalize
# Out:
# numpy, pandas imported...
# os imported
# warnings imported...
# time, date imported
# requests, json and urllib3 imported...
# <style>.container { width:100% !important; }</style>
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 31
#      27 display(HTML("<style>.container { width:100% !important; }</style>"))
#      29 get_ipython().run_line_magic('matplotlib', 'inline')
# ---> 31 from pandas.io.json import json_normalize
#
# ImportError: cannot import name 'json_normalize' from 'pandas.io.json' (C:\Users\WINNER\anaconda3\envs\finalenv\lib\site-packages\pandas\io\json\__init__.py)

# %% [markdown]
# # Read in csv files, text files and json files

# %%
print('Current Directory: {}' .format(os.getcwd()))
print("\n...")
print(os.listdir("../data_manipulation/data"))
print("/n...good, files are there")
# Out:
# Current Directory: C:\Users\WINNER\Documents\workspace\data_hackerman_finalproject\data_manipulation
#
# ...
# ['csv_file.csv', 'json_file.json', 'txt_file.txt']
# /n...good, files are there

# %%
# load Dataset
df1 = pd.read_csv("../data_manipulation/data/csv_file.csv")
print("'csv_file.csv' loaded...")
# Out:
# 'csv_file.csv' loaded...

# %%
df1.head()
# Out:
#    author.properties.friends  author.properties.status_count
# 0                       1689                           22566  \
# 1                        114                            1377
# 2                        568                            8375
# 3                       1845                           19394
# 4                       1617                           17922
#
#    author.properties.verified
# 0                       False  \
# 1                       False
# 2                       False
# 3                       False
# 4                       False
#
#                                                                                                                                    content.body
# 0                                                                                                       Can't believe I'm missing Love Island 😩  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   author.properties.friends       1000 non-null   int64
#  1   author.properties.status_count  1000 non-null   int64
#  2   author.properties.verified      1000 non-null   bool
#  3   content.body                    1000 non-null   object
#  4   location.country                1000 non-null   object
#  5   properties.platform             1000 non-null   object
#  6   properties.sentiment            1000 non-null   int64
#  7   location.latitude               1000 non-null   float64
#  8   location.longitude              1000 non-null   float64
# dtypes: bool(1), float64(2), int64(3), object(3)
# memory usage: 63.6+ KB

# %%
# load Dataset
df2 = pd.read_csv("../data_manipulation/data/txt_file.txt")
print("'txt_file.csv' loaded...")
# Out:
# 'txt_file.csv' loaded...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   author.properties.friends       1000 non-null   object
#  1   author.properties.verified      1000 non-null   object
#  2   location.longitude              999 non-null    float64
#  3   author.properties.status_count  999 non-null    float64
#  4   properties.sentiment            999 non-null    float64
#  5   location.latitude               999 non-null    float64
#  6   location.country                999 non-null    object
#  7   content.body                    999 non-null    object
#  8   properties.platform             998 non-null    object
# dtypes: float64(4), object(5)
# memory usage: 70.4+ KB

# %%
df2.head()
# Out:
#   author.properties.friends author.properties.verified  location.longitude
# 0                       632                      False               -2.32  \
# 1                       278                      False               -0.34
# 2                       169                      False               -0.28
# 3                       195                      False                0.03
# 4                       572                      False               -0.09
#
#    author.properties.status_count  properties.sentiment  location.latitude
# 0                       106490.00                  0.00              52.12  \
# 1                        31467.00                 -1.00              51.60
# 2                         1185.00                 -1.00              51.39
# 3                         2742.00                 -1.00              51.39
# 4                        18332.00                  0.00              51.36
#
#   location.country
# 0               GB  \
# 1               GB
# ...

# %% [markdown]
# # Combining the two datasets by conacatenating them into one dataframe

# %%
df0 = pd.concat([df1, df2], ignore_index=True)

# %%
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   author.properties.friends       2000 non-null   object
#  1   author.properties.status_count  1999 non-null   float64
#  2   author.properties.verified      2000 non-null   object
#  3   content.body                    1999 non-null   object
#  4   location.country                1999 non-null   object
#  5   properties.platform             1998 non-null   object
#  6   properties.sentiment            1999 non-null   float64
#  7   location.latitude               1999 non-null   float64
#  8   location.longitude              1999 non-null   float64
# dtypes: float64(4), object(5)
# memory usage: 140.8+ KB

# %%
df0.head()
# Out:
#   author.properties.friends  author.properties.status_count
# 0                      1689                        22566.00  \
# 1                       114                         1377.00
# 2                       568                         8375.00
# 3                      1845                        19394.00
# 4                      1617                        17922.00
#
#   author.properties.verified
# 0                      False  \
# 1                      False
# 2                      False
# 3                      False
# 4                      False
#
#                                                                                                                                    content.body
# 0                                                                                                       Can't believe I'm missing Love Island 😩  \
# ...

# %%
print('The result dataframe has {} rows and {} columns as expected.' .format(df0.shape[0], df0.shape[1]))
# Out:
# The result dataframe has 2000 rows and 9 columns as expected.

# %%
print('And we have a {} still.'. format(type(df0)))
# Out:
# And we have a <class 'pandas.core.frame.DataFrame'> still.

# %% [markdown]
# # Now join the two datasets with json data

# %%
#laod json object
with open("../data_manipulation/data/json_file.json") as f:
    df3 = json.load(f)

# %%
df3
# Out:
# [{'author': {'properties': {'friends': 150,
#     'verified': False,
#     'status_count': 583}},
#   'location': {'longitude': -1.4496120000000003,
#    'country': 'GB',
#    'latitude': 53.38322877572023},
#   'content': {'body': "To everyone tryin to snapchat me fuck off I'm ugly"},
#   'properties': {'sentiment': -1, 'platform': 'twitter'}},
#  {'author': {'properties': {'friends': 1321,
#     'verified': False,
#     'status_count': 86271}},
#   'location': {'longitude': -4.200440999999999,
#    'country': 'GB',
#    'latitude': 57.786631183916356},
#   'content': {'body': '@cammiescott have you ever been to Scotland? You should give Nessie a wee visit! (I live near her) #askcamscott'},
#   'properties': {'sentiment': -1, 'platform': 'twitter'}},
#  {'author': {'properties': {'friends': 1952,
#     'verified': False,
#     'status_count': 11785}},
#   'location': {'longitude': -0.07060350000000003,
#    'country': 'GB',
#    'latitude': 51.46469310439313},
# ...

# %% [markdown]
# # To make json readable as expected... must be flatten to pandas dataframe

# %%
df3 = json_normalize(df3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df3 = json_normalize(df3)
#
# NameError: name 'json_normalize' is not defined

# %% [markdown]
# NoW WE CAN VIEW THE HEAD AND INFO AFTER WE HAVE USED JSON_NORMALIZE

# %%
df3.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df3.head()
#
# AttributeError: 'list' object has no attribute 'head'

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   author.properties.friends       1000 non-null   int64
#  1   author.properties.verified      1000 non-null   bool
#  2   author.properties.status_count  1000 non-null   int64
#  3   location.longitude              1000 non-null   float64
#  4   location.country                1000 non-null   object
#  5   location.latitude               1000 non-null   float64
#  6   content.body                    1000 non-null   object
#  7   properties.sentiment            1000 non-null   int64
#  8   properties.platform             1000 non-null   object
# dtypes: bool(1), float64(2), int64(3), object(3)
# memory usage: 63.6+ KB

# %% [markdown]
# we concatenate the resulting dataframe with the earlier dataframe from df0

# %%
df = pd.concat([df0, df3], ignore_index=True)

# %%
print('The result dataframe has {} rows and {} columns as expected.' .format(df0.shape[0], df0.shape[1]))
# Out:
# The result dataframe has 2000 rows and 9 columns as expected.

# %%
print('Still a {}.'.format(type(df)))
# Out:
# Still a <class 'pandas.core.frame.DataFrame'>.

# %% [markdown]
# Let have a look on the resulting dataframe

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   author.properties.friends       3000 non-null   object
#  1   author.properties.status_count  2999 non-null   float64
#  2   author.properties.verified      3000 non-null   object
#  3   content.body                    2999 non-null   object
#  4   location.country                2999 non-null   object
#  5   properties.platform             2998 non-null   object
#  6   properties.sentiment            2999 non-null   float64
#  7   location.latitude               2999 non-null   float64
#  8   location.longitude              2999 non-null   float64
# dtypes: float64(4), object(5)
# memory usage: 211.1+ KB

# %% [markdown]
# .info() shows non- uniform of entries as a result of missing data. This will be look into at Data exploration

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined
